# %%
import pandas as pd
from pathlib import Path

# %%
DATA_PATH = Path("../data/raw/study_prompts.csv")

df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#        id          topic         subtopic  \
# 0  dl_001  deep_learning  backpropagation
# 1  dl_002  deep_learning  backpropagation
# 2  dl_003  deep_learning  backpropagation
# 3  dl_004  deep_learning  backpropagation
# 4  dl_005  deep_learning  backpropagation
#
#                                               prompt difficulty
# 0  Explain backpropagation in simple language for...       easy
# 1  What does the chain rule do during backpropaga...       easy
# 2  Why do neural networks use gradients during tr...       easy
# 3  Explain forward pass and backward pass in a ne...       easy
# 4  Why can vanishing gradients make deep networks...     medium
